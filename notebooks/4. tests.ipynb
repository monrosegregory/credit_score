# %%
# Data manipulation
import numpy as np
import pandas as pd
# Data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# Path
import os

# %%
pd.set_option('display.max_columns', None)

# %%
url = '/home/fernando_cir/code/monrosegregory/credit_score/raw_data/train.csv'
df = pd.read_csv(url)
df.head(2)
# Out:
# /tmp/ipykernel_67791/2273111201.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#        ID Customer_ID     Month           Name Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh  23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12            1824.843333                  3                4
# 1      19114.12                    NaN                  3                4
#
#    Interest_Rate Num_of_Loan  \
# 0              3           4
# 1              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
#
#   Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                      7                11.27                   4.0
# 1                    NaN                11.27                   4.0
#
#   Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0          _           809.98                  26.82262
# 1       Good           809.98                  31.94496
#
#       Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0  22 Years and 1 Months                    No            49.574949
# 1                    NaN                    No            49.574949
#
#   Amount_invested_monthly                Payment_Behaviour  \
# 0       80.41529543900253  High_spent_Small_value_payments
# 1      118.28022162236736   Low_spent_Large_value_payments
#
#       Monthly_Balance Credit_Score
# 0  312.49408867943663         Good
# 1  284.62916249607184         Good

# %%
df["Credit_Score"].unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
df[df["Credit_Score"] == "Poor"]
# Out:
#             ID Customer_ID     Month   Name   Age          SSN     Occupation  \
# 56      0x1656  CUS_0x5407   January   Annk  7580  500-92-6408  Media_Manager
# 57      0x1657  CUS_0x5407  February   Annk    30  500-92-6408  Media_Manager
# 58      0x1658  CUS_0x5407     March   Annk   30_  500-92-6408  Media_Manager
# 59      0x1659  CUS_0x5407     April   Annk    30  500-92-6408        _______
# 63      0x165d  CUS_0x5407    August   Annk    30  500-92-6408  Media_Manager
# ...        ...         ...       ...    ...   ...          ...            ...
# 99994  0x25fe8  CUS_0x942c     March  Nicks    25  078-73-5990       Mechanic
# 99995  0x25fe9  CUS_0x942c     April  Nicks    25  078-73-5990       Mechanic
# 99996  0x25fea  CUS_0x942c       May  Nicks    25  078-73-5990       Mechanic
# 99997  0x25feb  CUS_0x942c      June  Nicks    25  078-73-5990       Mechanic
# 99999  0x25fed  CUS_0x942c    August  Nicks    25  078-73-5990       Mechanic
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 56        34081.38_                    NaN                  8
# 57         34081.38            2611.115000                  8
# 58         34081.38                    NaN                  8
# 59         34081.38            2611.115000                  8
# 63         34081.38            2611.115000                  8
# ...             ...                    ...                ...
# 99994      39628.99            3359.415833                  4
# 99995      39628.99            3359.415833                  4
# 99996      39628.99            3359.415833                  4
# 99997      39628.99            3359.415833                  4
# 99999     39628.99_            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 56                   7             15           3
# 57                   7             15           3
# 58                   7             15           3
# 59                   7             15           3
# 63                   7             15           3
# ...                ...            ...         ...
# 99994                6              7           2
# 99995                6              7           2
# 99996                6              7           2
# 99997                6           5729           2
# 99999                6              7           2
#
#                                      Type_of_Loan  Delay_from_due_date  \
# 56     Not Specified, Auto Loan, and Student Loan                   30
# 57     Not Specified, Auto Loan, and Student Loan                   30
# 58     Not Specified, Auto Loan, and Student Loan                   31
# 59     Not Specified, Auto Loan, and Student Loan                   34
# 63     Not Specified, Auto Loan, and Student Loan                   30
# ...                                           ...                  ...
# 99994                 Auto Loan, and Student Loan                   20
# 99995                 Auto Loan, and Student Loan                   23
# 99996                 Auto Loan, and Student Loan                   18
# 99997                 Auto Loan, and Student Loan                   27
# 99999                 Auto Loan, and Student Loan                   18
#
#       Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 56                        11                17.13                   5.0
# 57                        14                17.13                   5.0
# 58                        14                17.13                   5.0
# 59                        14                21.13                   5.0
# 63                        14                17.13                   9.0
# ...                      ...                  ...                   ...
# 99994                      6                  9.5                   3.0
# 99995                      7                 11.5                   3.0
# 99996                      7                 11.5                   3.0
# 99997                      6                 11.5                   3.0
# 99999                      6                 11.5                   3.0
#
#       Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 56      Standard          1704.18                 24.448063
# 57             _          1704.18                 35.171160
# 58      Standard          1704.18                 35.111552
# 59             _          1704.18                 29.762159
# 63             _          1704.18                 33.823488
# ...          ...              ...                       ...
# 99994          _           502.38                 39.323569
# 99995          _           502.38                 34.663572
# 99996          _           502.38                 40.565631
# 99997       Good           502.38                 41.255522
# 99999       Good           502.38                 34.192463
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 56                        NaN                    NM            70.478333
# 57      14 Years and 8 Months                   Yes            70.478333
# 58      14 Years and 9 Months                   Yes            70.478333
# 59     14 Years and 10 Months                   Yes            70.478333
# 63      15 Years and 2 Months                   Yes            70.478333
# ...                       ...                   ...                  ...
# 99994   31 Years and 5 Months                    No            35.104023
# 99995   31 Years and 6 Months                    No            35.104023
# 99996   31 Years and 7 Months                    No            35.104023
# 99997   31 Years and 8 Months                    No            35.104023
# 99999  31 Years and 10 Months                    No            35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 56          162.4410091967751    Low_spent_Large_value_payments
# 57           38.4369827577036   High_spent_Large_value_payments
# 58          199.7207654954979    Low_spent_Large_value_payments
# 59         220.55219192916718    Low_spent_Small_value_payments
# 63          29.32636371091455  High_spent_Medium_value_payments
# ...                       ...                               ...
# 99994      140.58140274528395  High_spent_Medium_value_payments
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99999       167.1638651610451                            !@9#%8
#
#           Monthly_Balance Credit_Score
# 56     298.19215813115227         Poor
# 57     392.19618457022375         Poor
# 58      260.9124018324295         Poor
# 59      260.0809753987602         Poor
# 63      411.3068036170128         Poor
# ...                   ...          ...
# 99994          410.256158         Poor
# 99995          479.866228         Poor
# 99996           496.65161         Poor
# 99997          516.809083         Poor
# 99999          393.673696         Poor
#
# [28998 rows x 28 columns]

# %%
df["Payment_Behaviour"].value_counts()
# Out:
# Payment_Behaviour
# Low_spent_Small_value_payments      25513
# High_spent_Medium_value_payments    17540
# Low_spent_Medium_value_payments     13861
# High_spent_Large_value_payments     13721
# High_spent_Small_value_payments     11340
# Low_spent_Large_value_payments      10425
# !@9#%8                               7600
# Name: count, dtype: int64
